# %% [markdown]
# # Install all dependencies

# %%
# %pip install numpy
# %pip install scipy
# %pip install pyserial
# %pip install pyvisa
# %pip install opencv-python
# %pip install matplotlib
# %pip install pandas
# %pip install pyvista
# %pip install pymeshfix
# %pip install genicam
# %pip install harvesters
# %pip install ipympl
# %pip install trame
# %pip install trame-vuetify
# %pip install trame-vtk
# %pip install seaborn
# %pip install open3d
# %pip install trimesh
# %pip install networkx
# %pip install pymeshlab
# %pip install tqdm
# %pip install git+https://github.com/facebookresearch/segment-anything.git
# %pip install opencv-python pycocotools matplotlib onnxruntime onnx
# %pip install torch
# %pip install torchvision
# %pip install opencv-contrib-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\tools\fb-python\fb-python310\lib\site-packages\numpy-1.26.0-py3.10-win-amd64.egg (1.26.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in c:\users\jrp\appdata\roaming\python\python310\site-packages (1.11.3)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in c:\tools\fb-python\fb-python310\lib\site-packages\numpy-1.26.0-py3.10-win-amd64.egg (from scipy) (1.26.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyserial in c:\users\jrp\appdata\roaming\python\python310\site-packages (3.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyvisa in c:\users\jrp\appdata\roaming\python\python310\site-packages (1.13.0)
# Requirement already satisfied: typing-extensions in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pyvisa) (4.8.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\jrp\appdata\roaming\python\python310\site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.21.2 in c:\tools\fb-python\fb-python310\lib\site-packages\numpy-1.26.0-py3.10-win-amd64.egg (from opencv-python) (1.26.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\jrp\appdata\roaming\python\python310\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\tools\fb-python\fb-python310\lib\site-packages\numpy-1.26.0-py3.10-win-amd64.egg (from matplotlib) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\jrp\appdata\roaming\python\python310\site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.22.4 in c:\tools\fb-python\fb-python310\lib\site-packages\numpy-1.26.0-py3.10-win-amd64.egg (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pyvista in c:\users\jrp\appdata\roaming\python\python310\site-packages (0.42.2)
# Requirement already satisfied: matplotlib>=3.0.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pyvista) (3.8.0)
# Requirement already satisfied: numpy in c:\tools\fb-python\fb-python310\lib\site-packages\numpy-1.26.0-py3.10-win-amd64.egg (from pyvista) (1.26.0)
# Requirement already satisfied: pillow in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pyvista) (10.0.1)
# Requirement already satisfied: pooch in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pyvista) (1.7.0)
# Requirement already satisfied: scooby>=0.5.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pyvista) (0.7.4)
# Requirement already satisfied: vtk in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pyvista) (9.2.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.1->pyvista) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.1->pyvista) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.1->pyvista) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.1->pyvista) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.1->pyvista) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.1->pyvista) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.1->pyvista) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pooch->pyvista) (3.11.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pooch->pyvista) (2.31.0)
# Requirement already satisfied: six>=1.5 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.1->pyvista) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from requests>=2.19.0->pooch->pyvista) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from requests>=2.19.0->pooch->pyvista) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from requests>=2.19.0->pooch->pyvista) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from requests>=2.19.0->pooch->pyvista) (2023.7.22)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pymeshfix in c:\users\jrp\appdata\roaming\python\python310\site-packages (0.16.2)
# Requirement already satisfied: numpy>1.11.0 in c:\tools\fb-python\fb-python310\lib\site-packages\numpy-1.26.0-py3.10-win-amd64.egg (from pymeshfix) (1.26.0)
# Requirement already satisfied: pyvista>=0.30.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pymeshfix) (0.42.2)
# Requirement already satisfied: matplotlib>=3.0.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pyvista>=0.30.0->pymeshfix) (3.8.0)
# Requirement already satisfied: pillow in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pyvista>=0.30.0->pymeshfix) (10.0.1)
# Requirement already satisfied: pooch in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pyvista>=0.30.0->pymeshfix) (1.7.0)
# Requirement already satisfied: scooby>=0.5.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pyvista>=0.30.0->pymeshfix) (0.7.4)
# Requirement already satisfied: vtk in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pyvista>=0.30.0->pymeshfix) (9.2.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.1->pyvista>=0.30.0->pymeshfix) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.1->pyvista>=0.30.0->pymeshfix) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.1->pyvista>=0.30.0->pymeshfix) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.1->pyvista>=0.30.0->pymeshfix) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.1->pyvista>=0.30.0->pymeshfix) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.1->pyvista>=0.30.0->pymeshfix) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.1->pyvista>=0.30.0->pymeshfix) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pooch->pyvista>=0.30.0->pymeshfix) (3.11.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pooch->pyvista>=0.30.0->pymeshfix) (2.31.0)
# Requirement already satisfied: six>=1.5 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.1->pyvista>=0.30.0->pymeshfix) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from requests>=2.19.0->pooch->pyvista>=0.30.0->pymeshfix) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from requests>=2.19.0->pooch->pyvista>=0.30.0->pymeshfix) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from requests>=2.19.0->pooch->pyvista>=0.30.0->pymeshfix) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from requests>=2.19.0->pooch->pyvista>=0.30.0->pymeshfix) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: genicam in c:\tools\fb-python\fb-python310\lib\site-packages\genicam-1.3.0-py3.10-win-amd64.egg (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: harvesters in c:\tools\fb-python\fb-python310\lib\site-packages\harvesters-1.4.2.post0.dev3-py3.10.egg (1.4.2.post0.dev3)
# Requirement already satisfied: genicam>=1.2 in c:\tools\fb-python\fb-python310\lib\site-packages\genicam-1.3.0-py3.10-win-amd64.egg (from harvesters) (1.3.0)
# Requirement already satisfied: numpy in c:\tools\fb-python\fb-python310\lib\site-packages\numpy-1.26.0-py3.10-win-amd64.egg (from harvesters) (1.26.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipympl in c:\users\jrp\appdata\roaming\python\python310\site-packages (0.9.3)
# Requirement already satisfied: ipython<9 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipympl) (8.16.1)
# Requirement already satisfied: numpy in c:\tools\fb-python\fb-python310\lib\site-packages\numpy-1.26.0-py3.10-win-amd64.egg (from ipympl) (1.26.0)
# Requirement already satisfied: ipython-genutils in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: pillow in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipympl) (10.0.1)
# Requirement already satisfied: traitlets<6 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipympl) (5.11.2)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipympl) (8.1.1)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipympl) (3.8.0)
# Requirement already satisfied: backcall in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: decorator in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl) (2.16.1)
# Requirement already satisfied: stack-data in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl) (0.6.3)
# Requirement already satisfied: exceptiongroup in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl) (1.1.3)
# Requirement already satisfied: colorama in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.1.4)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib<4,>=3.4.0->ipympl) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\jrp\appdata\roaming\python\python310\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython<9->ipympl) (0.2.8)
# Requirement already satisfied: six>=1.5 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from stack-data->ipython<9->ipympl) (2.0.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from stack-data->ipython<9->ipympl) (2.4.0)
# Requirement already satisfied: pure-eval in c:\users\jrp\appdata\roaming\python\python310\site-packages (from stack-data->ipython<9->ipympl) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: trame in c:\users\jrp\appdata\roaming\python\python310\site-packages (3.2.7)
# Requirement already satisfied: trame-server>=2.12.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from trame) (2.12.0)
# Requirement already satisfied: trame-client>=2.12.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from trame) (2.12.2)
# Requirement already satisfied: wslink>=1.12.2 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from trame-server>=2.12.0->trame) (1.12.2)
# Requirement already satisfied: aiohttp<4 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from wslink>=1.12.2->trame-server>=2.12.0->trame) (3.8.5)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from aiohttp<4->wslink>=1.12.2->trame-server>=2.12.0->trame) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from aiohttp<4->wslink>=1.12.2->trame-server>=2.12.0->trame) (3.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from aiohttp<4->wslink>=1.12.2->trame-server>=2.12.0->trame) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from aiohttp<4->wslink>=1.12.2->trame-server>=2.12.0->trame) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from aiohttp<4->wslink>=1.12.2->trame-server>=2.12.0->trame) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from aiohttp<4->wslink>=1.12.2->trame-server>=2.12.0->trame) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from aiohttp<4->wslink>=1.12.2->trame-server>=2.12.0->trame) (1.3.1)
# Requirement already satisfied: idna>=2.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from yarl<2.0,>=1.0->aiohttp<4->wslink>=1.12.2->trame-server>=2.12.0->trame) (3.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: trame-vuetify in c:\users\jrp\appdata\roaming\python\python310\site-packages (2.3.1)
# Requirement already satisfied: trame-client in c:\users\jrp\appdata\roaming\python\python310\site-packages (from trame-vuetify) (2.12.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: trame-vtk in c:\users\jrp\appdata\roaming\python\python310\site-packages (2.5.8)
# Requirement already satisfied: trame-client in c:\users\jrp\appdata\roaming\python\python310\site-packages (from trame-vtk) (2.12.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\jrp\appdata\roaming\python\python310\site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\tools\fb-python\fb-python310\lib\site-packages\numpy-1.26.0-py3.10-win-amd64.egg (from seaborn) (1.26.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: open3d in c:\users\jrp\appdata\roaming\python\python310\site-packages (0.17.0)
# Requirement already satisfied: numpy>=1.18.0 in c:\tools\fb-python\fb-python310\lib\site-packages\numpy-1.26.0-py3.10-win-amd64.egg (from open3d) (1.26.0)
# Requirement already satisfied: dash>=2.6.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from open3d) (2.13.0)
# Requirement already satisfied: werkzeug>=2.2.3 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from open3d) (2.2.3)
# Requirement already satisfied: nbformat==5.7.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from open3d) (5.7.0)
# Requirement already satisfied: configargparse in c:\users\jrp\appdata\roaming\python\python310\site-packages (from open3d) (1.7)
# Requirement already satisfied: ipywidgets>=8.0.4 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from open3d) (8.1.1)
# Requirement already satisfied: fastjsonschema in c:\users\jrp\appdata\roaming\python\python310\site-packages (from nbformat==5.7.0->open3d) (2.18.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from nbformat==5.7.0->open3d) (4.19.1)
# Requirement already satisfied: jupyter-core in c:\users\jrp\appdata\roaming\python\python310\site-packages (from nbformat==5.7.0->open3d) (5.3.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from nbformat==5.7.0->open3d) (5.11.2)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from dash>=2.6.0->open3d) (2.2.5)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from dash>=2.6.0->open3d) (5.17.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from dash>=2.6.0->open3d) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from dash>=2.6.0->open3d) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from dash>=2.6.0->open3d) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from dash>=2.6.0->open3d) (4.8.0)
# Requirement already satisfied: requests in c:\users\jrp\appdata\roaming\python\python310\site-packages (from dash>=2.6.0->open3d) (2.31.0)
# Requirement already satisfied: retrying in c:\users\jrp\appdata\roaming\python\python310\site-packages (from dash>=2.6.0->open3d) (1.3.4)
# Requirement already satisfied: ansi2html in c:\users\jrp\appdata\roaming\python\python310\site-packages (from dash>=2.6.0->open3d) (1.8.0)
# Requirement already satisfied: nest-asyncio in c:\users\jrp\appdata\roaming\python\python310\site-packages (from dash>=2.6.0->open3d) (1.5.8)
# Requirement already satisfied: setuptools in c:\tools\fb-python\fb-python310\lib\site-packages (from dash>=2.6.0->open3d) (65.5.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipywidgets>=8.0.4->open3d) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipywidgets>=8.0.4->open3d) (8.16.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipywidgets>=8.0.4->open3d) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipywidgets>=8.0.4->open3d) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from werkzeug>=2.2.3->open3d) (2.1.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from Flask<2.3.0,>=1.0.4->dash>=2.6.0->open3d) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from Flask<2.3.0,>=1.0.4->dash>=2.6.0->open3d) (2.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from Flask<2.3.0,>=1.0.4->dash>=2.6.0->open3d) (8.1.7)
# Requirement already satisfied: backcall in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.0)
# Requirement already satisfied: decorator in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.16.1)
# Requirement already satisfied: stack-data in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.6.3)
# Requirement already satisfied: exceptiongroup in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (1.1.3)
# Requirement already satisfied: colorama in c:\users\jrp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from jsonschema>=2.6->nbformat==5.7.0->open3d) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from jsonschema>=2.6->nbformat==5.7.0->open3d) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from jsonschema>=2.6->nbformat==5.7.0->open3d) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from jsonschema>=2.6->nbformat==5.7.0->open3d) (0.10.4)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (8.2.3)
# Requirement already satisfied: packaging in c:\users\jrp\appdata\roaming\python\python310\site-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (23.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from jupyter-core->nbformat==5.7.0->open3d) (3.11.0)
# Requirement already satisfied: pywin32>=300 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from jupyter-core->nbformat==5.7.0->open3d) (306)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from requests->dash>=2.6.0->open3d) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from requests->dash>=2.6.0->open3d) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from requests->dash>=2.6.0->open3d) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from requests->dash>=2.6.0->open3d) (2023.7.22)
# Requirement already satisfied: six>=1.7.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from retrying->dash>=2.6.0->open3d) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\jrp\appdata\roaming\python\python310\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.8)
# Requirement already satisfied: executing>=1.2.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.0.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\jrp\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.4.0)
# Requirement already satisfied: pure-eval in c:\users\jrp\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: trimesh in c:\users\jrp\appdata\roaming\python\python310\site-packages (3.23.5)
# Requirement already satisfied: numpy in c:\tools\fb-python\fb-python310\lib\site-packages\numpy-1.26.0-py3.10-win-amd64.egg (from trimesh) (1.26.0)
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: networkx in c:\users\jrp\appdata\roaming\python\python310\site-packages (3.1)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tqdm in c:\users\jrp\appdata\roaming\python\python310\site-packages (4.66.1)
# Requirement already satisfied: colorama in c:\users\jrp\appdata\roaming\python\python310\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Test the dependencies

# %%
import numpy as np
import cv2 as cv
import pandas as pd
import pyvista as pv
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pylab as plt
import seaborn

import open3d as o3d
import pymeshfix as mf

import genicam
import harvesters

import trimesh
import networkx

#import pymeshlab
import tqdm
